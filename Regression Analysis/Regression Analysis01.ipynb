# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.8 MB 2.0 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/9.8 MB 6.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/9.8 MB 8.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.8 MB 9.3 MB/s eta 0:00:01
#    -------- ------------------------------- 2.2/9.8 MB 9.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.8/9.8 MB 9.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.2/9.8 MB 9.8 MB/s eta 0:00:01
#    --------------- ------------------------ 3.8/9.8 MB 10.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.4/9.8 MB 10.3 MB/s eta 0:00:01
#    ------------------- -------------------- 4.8/9.8 MB 10.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.4/9.8 MB 10.5 MB/s eta 0:00:01
#    ------------------------ --------------- 5.9/9.8 MB 10.5 MB/s eta 0:00:01
#    -------------------------- ------------- 6.5/9.8 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.0/9.8 MB 10.9 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.8 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 11.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.8 MB 11.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 10.6 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ---------------------------------------- 233.9/233.9 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2

# %%
import pandas as pd
import statsmodels.api as sm

# Load the dataset
url = "https://raw.githubusercontent.com/justmarkham/scikit-learn-videos/master/data/Advertising.csv"
data = pd.read_csv(url, index_col=0)
print(data)
# Define the independent variables (add a constant for the intercept)
X = data[['TV', 'Radio', 'Newspaper']]
X = sm.add_constant(X)
print(X)

# Define the dependent variable
y = data['Sales']

# Fit the model using the independent and dependent variables
model = sm.OLS(y, X).fit()

# Print the summary of the model
print(model.summary())
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]
#      const     TV  Radio  Newspaper
# 1      1.0  230.1   37.8       69.2
# 2      1.0   44.5   39.3       45.1
# 3      1.0   17.2   45.9       69.3
# 4      1.0  151.5   41.3       58.5
# 5      1.0  180.8   10.8       58.4
# ..     ...    ...    ...        ...
# 196    1.0   38.2    3.7       13.8
# 197    1.0   94.2    4.9        8.1
# 198    1.0  177.0    9.3        6.4
# 199    1.0  283.6   42.0       66.2
# 200    1.0  232.1    8.6        8.7
#
# [200 rows x 4 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 05 Sep 2024   Prob (F-statistic):           1.58e-96
# Time:                        15:55:36   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
